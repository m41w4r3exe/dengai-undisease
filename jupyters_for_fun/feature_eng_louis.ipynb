# %%
from best_pipeline import best_pipeline_intown
from cleaning import get_train_data
import matplotlib.pyplot as plt
import numpy as np

Xsj, y = get_train_data("sj")
pipeline = best_pipeline_intown(Xsj)
pipeline.fit(Xsj, y)

importances = pipeline.steps[1][1].feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots()
ax.barh(range(len(importances)), importances[indices])
ax.set_yticks(range(len(importances)))
_ = ax.set_yticklabels(np.array(Xsj.columns)[indices])

# %%
Xiq, y = get_train_data("iq")
pipeline = best_pipeline_intown(Xiq)
pipeline.fit(Xiq, y)

importances = pipeline.steps[1][1].feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots()
ax.barh(range(len(importances)), importances[indices])
ax.set_yticks(range(len(importances)))
_ = ax.set_yticklabels(np.array(Xiq.columns)[indices])

# %%
from evaluate import cross_evaluate_for_city, get_save_params
from best_pipeline import best_pipeline_intown
from cleaning import get_train_data

score_sj, mae_mean_sj, mae_std_sj = cross_evaluate_for_city("sj")
score_iq, mae_mean_iq, mae_std_iq = cross_evaluate_for_city("iq")

get_save_params(
    score_sj, score_iq, mae_mean_sj, mae_std_sj, mae_mean_iq, mae_std_iq
)
# Out:
# Results for SJ:
# Mean Absolute Error:     30.485 +/- 23.110
#
#
# Results for IQ:
# Mean Absolute Error:     6.733 +/- 2.224

# %%
Xsj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 936 entries, 0 to 935
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   year                         936 non-null    int64
#  1   weekofyear                   936 non-null    int64
#  2   reanalysis_dew_point_temp_k  930 non-null    float64
#  3   temp_avg                     930 non-null    float64
#  4   max_temp_avg                 930 non-null    float64
#  5   min_temp_avg                 930 non-null    float64
#  6   temp_range_avg               930 non-null    float64
#  7   humidity_avg                 930 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 65.8 KB
