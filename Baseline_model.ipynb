# %%
import pandas as pd


trainX = pd.read_csv('./data/dengue_features_train.csv', index_col=0)
trainY = pd.read_csv('./data/dengue_labels_train.csv', index_col=0)

trainX.head()
# Out:
#       year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# city
# sj    1990          18      1990-04-30  0.122600  0.103725  0.198483
# sj    1990          19      1990-05-07  0.169900  0.142175  0.162357
# sj    1990          20      1990-05-14  0.032250  0.172967  0.157200
# sj    1990          21      1990-05-21  0.128633  0.245067  0.227557
# sj    1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# city
# sj    0.177617                 12.42             297.572857
# sj    0.155486                 22.82             298.211429
# sj    0.170843                 34.54             298.781429
# sj    0.235886                 15.36             298.987143
# sj    0.247340                  7.52             299.518571
#
#       reanalysis_avg_temp_k  ...  reanalysis_precip_amt_kg_per_m2  \
# city                         ...
# sj               297.742857  ...                            32.00
# ...

# %%
trainX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1456 entries, sj to iq
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   year                                   1456 non-null   int64
#  1   weekofyear                             1456 non-null   int64
#  2   week_start_date                        1456 non-null   object
#  3   ndvi_ne                                1262 non-null   float64
#  4   ndvi_nw                                1404 non-null   float64
#  5   ndvi_se                                1434 non-null   float64
#  6   ndvi_sw                                1434 non-null   float64
#  7   precipitation_amt_mm                   1443 non-null   float64
#  8   reanalysis_air_temp_k                  1446 non-null   float64
#  9   reanalysis_avg_temp_k                  1446 non-null   float64
# ...
