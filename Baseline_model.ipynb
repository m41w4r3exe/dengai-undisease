# %%
import pandas as pd
import numpy as np
trainX = pd.read_csv('./data/dengue_features_train.csv')
trainY = pd.read_csv('./data/dengue_labels_train.csv')
trainX.head(), trainY.head()
# Out:
# (  city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
#  0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
#  1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
#  2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
#  3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
#  4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#      ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
#  0  0.177617                 12.42             297.572857  ...
#  1  0.155486                 22.82             298.211429  ...
#  2  0.170843                 34.54             298.781429  ...
#  3  0.235886                 15.36             298.987143  ...
#  4  0.247340                  7.52             299.518571  ...
#
#     reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
#  0                            32.00                             73.365714
# ...

# %%
#check data alignment
np.corrcoef(np.array(trainX.weekofyear), np.array(trainY.iloc[:,2]))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
#check duplicates
print(f' trainX duplicates? {trainX.duplicated().unique()}')
print(f' trainY duplicates? {trainY.duplicated().unique()}')
# Out:
#  trainX duplicates? [False]
#  trainY duplicates? [False]

# %%
target = trainY.iloc[:,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/jean/WORK/DSR_2022_b32/mini_competition/dengai-undisease/Baseline_model.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jean/WORK/DSR_2022_b32/mini_competition/dengai-undisease/Baseline_model.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> target = trainY.iloc[:,4]
#
# File ~/opt/anaconda3/envs/dsr-minicomp/lib/python3.8/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# ...

# %%
trainX.describe().T
# Out:
#                                        count  mean  std  min  25%  50%  75%  \
# year                                     0.0   NaN  NaN  NaN  NaN  NaN  NaN
# weekofyear                               0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ndvi_ne                                  0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ndvi_nw                                  0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ndvi_se                                  0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ndvi_sw                                  0.0   NaN  NaN  NaN  NaN  NaN  NaN
# precipitation_amt_mm                     0.0   NaN  NaN  NaN  NaN  NaN  NaN
# reanalysis_air_temp_k                    0.0   NaN  NaN  NaN  NaN  NaN  NaN
# reanalysis_avg_temp_k                    0.0   NaN  NaN  NaN  NaN  NaN  NaN
# reanalysis_dew_point_temp_k              0.0   NaN  NaN  NaN  NaN  NaN  NaN
# reanalysis_max_air_temp_k                0.0   NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
trainX.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %%
import matplotlib.pyplot as plt

# %%
trainX.info(), trainY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...
